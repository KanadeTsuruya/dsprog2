# %% [markdown]
# ### 仮説
#
# 「平均年収で大きな格差がある港区と足立区において、アルバイト求人の時給にも同様の格差が存在する。港区の求人の方が、足立区の求人よりも平均時給が高い。」
#
# 東京23区内の平均年収データによると、港区が最も高く、足立区が最も低いことが判明している。この地域間の経済格差は、アルバイトやパート求人の時給にも反映されているのではないかと考えた。
# この仮説の検証により、地域の経済状況が非正規雇用の賃金水準にどの程度影響を与えているかを明らかにすることができる。また、同一労働市場である東京都内でも、地域による賃金格差が存在するかを確認することができる。

# %% [markdown]
# ### スクレイピングのコード解説
#
# 1. データベース設計と作成
#
#
# * SQLiteを採用し、単一ファイルでデータを管理
# * 自動増分のID、会社名、時給、地区名、タイムスタンプを持つテーブル構造
# * CREATE TABLE IF NOT EXISTS で重複作成を防止
#
#
# 2. スクレイピング前の準備
#
#
# * 正規表現パターンを事前にコンパイルして処理を効率化
# * データベース接続を確立
# * ページ数の上限を設定（デフォルト50ページ）
#
#
# 3. ページ取得とエラー処理
#
#
# * URLを動的に生成してページごとにアクセス
# * 3秒のインターバルでサーバー負荷を分散
# * ステータスコード200以外は処理を中断
#
#
# 4. データ抽出の工夫
#
#
# * HTML構造に依存しない柔軟なセレクタ指定
# * 会社名と時給を別々に取得し、データの整合性を確保
# * 無効なデータの自動スキップ機能
#
#
# 5. データクレンジング
#
#
# * 1000円未満の時給を除外
# * 正規表現で数値のみを抽出
# * 特殊なケース（1600円台）の標準化
#
#
# 6. データベース保存の安全性
#
#
# * SQLパラメータ化でインジェクション対策
# * トランザクション単位でのコミット
# * 保存時の即時エラー検出
#
#
# 7. 進捗と結果の可視化
#
#
# * リアルタイムの保存状況表示
# * 区ごとの集計結果の自動計算
# * 平均時給と総件数の表示
#
#
# 8. 拡張性への配慮
#
#
# * 地区名をパラメータ化
# * URL指定で異なる地域のデータ取得が可能
# * テーブル構造で複数地区のデータを管理

# %% [markdown]
# #### 港区のスクレイピング

# %%
import re
import csv
import time
import requests
from bs4 import BeautifulSoup

def scrape_and_save_to_csv(base_url, csv_filename, max_pages=50):
    """
    base_url:
        ページ番号以外の共通部分。末尾に「?pageNo={page}」を付与して利用します。

    csv_filename:
        CSV出力のファイル名。

    max_pages:
        安全のための最大ページ数。デフォルトは50ですが、必要に応じて増減してください。
    """

    results = []

    # 正規表現パターン: "1600" の直後に4桁の数字が続くか → "1600" に置換
    pattern_remove_1600 = re.compile(r'1600\d{4}')

    for page_no in range(1, max_pages+1):
        # ページURL生成
        url = f"{base_url}?pageNo={page_no}"

        print(f"Fetching page: {url}")

        # リクエスト 前に3秒待機
        time.sleep(3)

        # ページ取得
        response = requests.get(url)
        # エラーなどでページが存在しない場合はそこで終了
        if response.status_code != 200:
            print(f"Page {page_no} not found (status: {response.status_code}). Stop.")
            break

        html_content = response.text
        soup = BeautifulSoup(html_content, 'html.parser')

        # カード単位で求人情報を取得（構造によって変更してください）
        # 例: "section.jobOfferCard" など、実際のHTMLを確認して適宜変更。
        # 以下は汎用的に "section" を全部取ってきて、その中に会社名・時給があるかを探す例。
        cards = soup.find_all("section")

        # フラグ: 1ページ分のcardが0件 または 有効なcardが何もない → 次のページ無さそうなら終了
        valid_card_found = False

        for card in cards:
            # 会社名を取得
            company_name_elem = card.select_one("div.shopNameWrap > h2")
            if not company_name_elem:
                continue
            company_name = company_name_elem.get_text(strip=True)

            # 時給を取得
            wage_elem = card.select_one("li.baseInformationSet.wage > div.baseInformationFirstContent")
            if not wage_elem:
                continue

            wage_text_original = wage_elem.get_text(strip=True)

            # "1600" のあとに4桁の数字 → "1600" に置換
            wage_text_fixed = re.sub(pattern_remove_1600, '1600', wage_text_original)

            # 数値抽出
            # 例: "時給1600～2000円" → ['1600','2000']
            # 最初の数字を最低時給とする
            nums = re.findall(r'\d+', wage_text_fixed)
            if not nums:
                continue

            min_wage = int(nums[0])  # 最初の数字を最低時給とみなす

            # 3桁以下(例: 100 ~ 999以下)は無視する
            if min_wage < 1000:
                # 例: 900とか700は日当表記などの可能性があるのでスキップ
                continue

            # ここまでこれたら有効データ
            valid_card_found = True

            results.append({
                "company_name": company_name,
                "wage_info": min_wage
            })

        # 有効なカードが0件の場合は「次のページはない」と判断して終了してもよい
        # ただし、中には他のページがまだある場合もあるので、判断が難しい場合は
        # ここでは card が見つからなくても break はしないことにします。
        # もし、次ページでは求人が本当にない、かつ 404 にもならないケースがあれば
        # 追加で条件を入れる必要があります。
        if not valid_card_found:
            print(f"No valid job found on page {page_no}. Stop.")
            break

    # すべてのページを取得後、CSV出力
    with open(csv_filename, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=["company_name", "wage_info"])
        writer.writeheader()
        writer.writerows(results)

    # コンソールにも出力確認
    for row in results:
        print(f"{row['company_name']},{row['wage_info']}")


if __name__ == "__main__":
    # base_url は「?pageNo=」より前の部分
    # 例: "https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/"
    base_url = "https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/"
    csv_filename = "wage_info.csv"

    scrape_and_save_to_csv(base_url, csv_filename)
    print("==== CSV出力が完了しました ====")
# Out:
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=1
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=2
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=3
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=4
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=5
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=6
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=7
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=8
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=9
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=10
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=11
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=12
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=13
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=14
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=15
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=16
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=17
# Fetching page: https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/?pageNo=18
# No valid job found on page 18. Stop.
# 株式会社橘組　東京営業所,2000
# 株式会社橘組　東京営業所,2000
# 株式会社スギハラサービスクリエイツ（アニヴェルセル表参道）,1400
# 株式会社アシスト 新宿本社,1750
# 株式会社Globridge かき家　こだはる,1350
# 有限会社品川配ぜん人紹介所 【勤務地：ザ・リッツ・カールトン東京】,1450
# 株式会社アシスト 新宿本社,1750
# 株式会社アシスト 新宿本社,1750
# 有限会社品川配ぜん人紹介所 【勤務地：品川エリア】,1600
# 株式会社H.R.M.（勤務地：港区エリア）,1400
# 明治記念館,1500
# 株式会社東邦サービス（勤務地：東京都港区赤坂）,2850
# 株式会社東邦サービス（勤務地：グランドプリンスホテル高輪）,1600
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※溜池山王ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:扇橋交通株式会社本社営業所)※新橋ｴﾘｱ,1400
# シグマアテンドサービス株式会社（勤務地：都内の有名ホテル）,1600
# 株式会社ワークオール/池袋本社　［赤坂エリア］,1200
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※三田ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※浜松町ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※浜松町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※赤坂ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※虎ﾉ門ﾋﾙｽﾞｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※新橋ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※白金台ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※広尾ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※広尾ｴﾘｱ,2000
# 株式会社ワークオール/池袋本社　［新橋エリア］,1200
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※表参道ｴﾘｱ,1800
# ザ・プリンスパークタワー東京（紹介元：株式会社Ｈ.Ｒ.Ｍ. ）,1400
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※白金台ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※高輪台ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※青山一丁目ｴﾘｱ,2000
# 株式会社ワークオール/池袋本社　［品川エリア］,1200
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※赤坂ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※田町ｴﾘｱ,2000
# 有限会社あさのコーポレーション　勤務地：ジャヌ東京【001】,1600
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※表参道ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:扇橋交通株式会社本社営業所)※六本木ｴﾘｱ,1400
# グランドプリンスホテル高輪（紹介元：株式会社Ｈ.Ｒ.Ｍ. ）,1600
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※六本木ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※新橋ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※虎ﾉ門ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※芝公園ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※赤坂ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※品川ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:扇橋交通株式会社本社営業所)※田町ｴﾘｱ,1400
# 紹介元:GO株式会社(紹介先:扇橋交通株式会社本社営業所)※田町ｴﾘｱ,1400
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※新橋ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※三田ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※田町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※麻布十番ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※神谷町ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※赤坂見附ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※麻布十番ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※青山一丁目ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※六本木一丁目ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※六本木ｴﾘｱ,2000
# 株式会社ワークオール/池袋本社　［六本木エリア］,1200
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※御成門ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※お台場海浜公園ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※汐留ｴﾘｱ,2000
# 株式会社ワークオール/池袋本社　［神谷町エリア］,1200
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※外苑前ｴﾘｱ,2000
# 株式会社ワークオール/池袋本社　［外苑前エリア］,1200
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※赤坂見附ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※神谷町ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※田町ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※外苑前ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※外苑前ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※表参道ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※六本木ｴﾘｱ,1800
# 有限会社あさのコーポレーション　勤務地：品川【001】,1650
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※神谷町ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※虎ﾉ門ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※浜松町ｴﾘｱ,2000
# 株式会社Globridge かき家　こだはる,1300
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※品川ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※外苑前ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※六本木一丁目ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※虎ﾉ門ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※品川ｴﾘｱ,2000
# 株式会社ワークオール/池袋本社　［虎ノ門エリア］,1200
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※大門ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※神谷町ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※広尾ｴﾘｱ,2000
# 株式会社ワークオール/池袋本社　［青山一丁目エリア］,1200
# 紹介元:GO株式会社(紹介先:扇橋交通株式会社本社営業所)※品川ｴﾘｱ,1400
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※虎ﾉ門ﾋﾙｽﾞｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社品川営業所)※白金高輪ｴﾘｱ,2000
# 株式会社ワークオール/池袋本社　［虎ノ門ヒルズエリア］,1200
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※六本木一丁目ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※六本木一丁目ｴﾘｱ,1800
# 株式会社エボルカ/東京本社,1500
# 株式会社エボルカ/東京本社,1500
# 株式会社エボルカ/東京本社,1500
# 株式会社エボルカ/東京本社,1500
# 株式会社エボルカ/東京本社,1500
# 株式会社エボルカ/東京本社,1500
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※外苑前ｴﾘｱ,1800
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社麻野配ぜん人紹介所　勤務地：新橋駅周辺エリア【001】,1600
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※青山一丁目ｴﾘｱ,1800
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※赤坂ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※浜松町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※品川ｴﾘｱ,1800
# 株式会社麻野配ぜん人紹介所　勤務地：表参道駅周辺エリア【001】,1600
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※麻布十番ｴﾘｱ,1800
# 株式会社ワークオール/池袋本社　［乃木坂エリア］,1200
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※表参道ｴﾘｱ,1800
# 株式会社橘組　東京営業所,2000
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※新橋ｴﾘｱ,1800
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※赤坂見附ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※六本木ｴﾘｱ,1800
# 株式会社ワークオール/池袋本社　［お台場海浜公園エリア］,1200
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※白金台ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※広尾ｴﾘｱ,1800
# 有限会社あさのコーポレーション　勤務地：アンダーズ東京【h】,1600
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社ワークオール/池袋本社　［六本木エリア］,1200
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※三田ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※芝公園ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※虎ﾉ門ﾋﾙｽﾞｴﾘｱ,1800
# テイケイトレード株式会社　新宿支店/521,1280
# 株式会社スギハラサービスクリエイツ　赤羽橋駅,1600
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# ライクスタッフィング株式会社/lwez3,1400
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※白金高輪ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※新橋ｴﾘｱ,1800
# 株式会社スギハラサービスクリエイツ　白金台駅,1600
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※神谷町ｴﾘｱ,1800
# 株式会社サンライズ　池袋営業所,1750
# 株式会社橘組　東京営業所,2000
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※神谷町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※六本木一丁目ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※広尾ｴﾘｱ,1800
# 株式会社橘組　東京営業所,2000
# 株式会社橘組　東京営業所,2000
# 株式会社橘組　東京営業所,2000
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社スギハラサービスクリエイツ　品川エリア,1600
# 株式会社マイワーク　新宿営業所　（2590112000※AP・派遣）,1500
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※赤坂ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※お台場海浜公園ｴﾘｱ,1800
# 株式会社橘組　東京営業所,2000
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※汐留ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※麻布十番ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※大門ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※田町ｴﾘｱ,1800
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社マイワーク　新宿営業所　（2590112000※AP・派遣）,1500
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※白金台ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※六本木ｴﾘｱ,1800
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※浜松町ｴﾘｱ,1800
# ライクスタッフィング株式会社/lwez3,1400
# 有限会社あさのコーポレーション　勤務地：乃木坂駅周辺【001】,1600
# 有限会社あさのコーポレーション　勤務地：乃木坂駅周辺【001】,1600
# 株式会社スギハラサービスクリエイツ　表参道駅,1600
# 株式会社スギハラサービスクリエイツ　表参道エリア,1600
# 株式会社ワークオール/池袋本社　［溜池山王エリア］,1200
# 株式会社パソナフォスター ※勤務地：港区,1350
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社マイワーク　新宿営業所　（2590112000※AP・派遣）,1500
# 株式会社スギハラサービスクリエイツ　六本木駅,1600
# 株式会社ワークオール/池袋本社　［御成門エリア］,1200
# 有限会社あさのコーポレーション　勤務地：六本木ヒルズクラブ【001】,1600
# 株式会社橘組　東京営業所,2000
# 株式会社マイワーク　錦糸町営業所　（2590112000※AP・派遣）,1370
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※三田ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※青山一丁目ｴﾘｱ,1800
# 株式会社ワークオール/池袋本社　［広尾エリア］,1200
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※六本木一丁目ｴﾘｱ,1800
# 株式会社スギハラサービスクリエイツ　麻布十番駅,1600
# 株式会社ディースパーク  新宿オフィス [勤務地:品川エリア],1350
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※御成門ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※神谷町ｴﾘｱ,1800
# 株式会社麻野配ぜん人紹介所　勤務地：三田駅周辺エリア【001】,1600
# 株式会社スギハラサービスクリエイツ　品川駅,1600
# 株式会社スギハラサービスクリエイツ　品川駅,1600
# 株式会社麻野配ぜん人紹介所　勤務地：ジャヌ東京※2023年秋オープン予定【001】,1600
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※神谷町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※高輪台ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※虎ﾉ門ﾋﾙｽﾞｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※外苑前ｴﾘｱ,1800
# 株式会社ワークオール/池袋本社　［竹芝エリア］,1200
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※品川ｴﾘｱ,1800
# ライクスタッフィング株式会社/lwez3,1400
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※虎ﾉ門ｴﾘｱ,1800
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※表参道ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※田町ｴﾘｱ,1800
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社スギハラサービスクリエイツ　三田駅,1600
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※赤坂見附ｴﾘｱ,1800
# 株式会社スギハラサービスクリエイツ　赤坂駅,1600
# 有限会社あさのコーポレーション　勤務地：六本木ヒルズクラブ【001】,1600
# 株式会社スギハラサービスクリエイツ　新橋駅,1600
# 紹介元:GO株式会社(紹介先:荏原交通株式会社本社営業所)※虎ﾉ門ｴﾘｱ,1800
# 株式会社ワークオール/池袋本社　［神谷町エリア］,1200
# 株式会社ワークオール/池袋本社　［神谷町エリア］,1200
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社品川営業所)※溜池山王ｴﾘｱ,1800
# 株式会社ワークオール/池袋本社　［赤羽橋エリア］,1200
# 株式会社ワークオール/池袋本社　［北品川エリア］,1200
# 株式会社橘組　東京営業所,2000
# 株式会社レジェンドプロモーション／※勤務地：赤坂駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：六本木一丁目駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：大門駅周辺,1700
# 株式会社フルキャスト　東京支社　（品川エリア）/MN0124G-AAX,1300
# 株式会社レジェンドプロモーション／※勤務地：新橋駅周辺,1700
# 株式会社フルキャスト　東京支社　（浜松町エリア）/MN0124G-AGN,1500
# 株式会社フルキャスト　東京支社　（乃木坂エリア）/MN0124G-ACK,1200
# 株式会社レジェンドプロモーション／※勤務地：三田駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：六本木駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：白金台駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：乃木坂駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：表参道駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：外苑前駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：青山一丁目駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：品川駅周辺,1700
# 株式会社フルキャスト　東京支社　（台場エリア）/MN0124G-ACW,1200
# 株式会社レジェンドプロモーション／※勤務地：御成門駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：神谷町駅周辺,1700
# 株式会社レジェンドプロモーション／※勤務地：麻布十番駅周辺,1700
# 株式会社グランシーズ（六本木エリアのお仕事）お仕事NO_001,1400
# テイケイワークス東京　新宿支店/TWT160,1355
# テイケイワークス東京　新宿支店/TWT160,1355
# 株式会社エスケイコンサルタント　横浜支店/sk702,1200
# 株式会社ルフト・メディカルケア（田町）,2000
# テイケイワークス東京　新宿支店/TWT160,1312
# ディアスタッフ株式会社_採用窓口【003】※六本木エリア【案件No.589】,1500
# 株式会社グランシーズ（青山一丁目エリアのお仕事）お仕事NO_001,1400
# 株式会社ルフト・メディカルケア（品川）,1900
# 株式会社グランシーズ（新橋エリアのお仕事）お仕事NO_001,1400
# テイケイワークス東京　新宿支店/TWT160,1312
# 株式会社サンライズ　池袋営業所,1750
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社グランシーズ（品川エリアのお仕事）お仕事NO_001,1400
# 株式会社アシスト 新宿本社,1750
# 株式会社ホリウチ・トータルサービス　外苑前エリア,1250
# 株式会社グランシーズ（神谷町エリアのお仕事）お仕事NO_001,1400
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# ヨウコーほっとスタッフ,1900
# テイケイワークス株式会社　池袋支店/TW153,1350
# 株式会社ルフト・メディカルケア（三田）,2000
# ディアスタッフ株式会社_採用窓口【003】※麻布十番エリア【案件No.589】,1500
# 株式会社ルフト・メディカルケア（泉岳寺）,2000
# 株式会社グランシーズ（新橋エリアのお仕事）お仕事NO_001,1400
# ディアスタッフ株式会社_採用窓口【003】※品川エリア【案件No.10】,1500
# 株式会社ルフト・メディカルケア（高輪ゲートウェイ）,1900
# 株式会社ルフト・メディカルケア（浜松町）,1900
# 株式会社エスケイコンサルタント　錦糸町支店/sk602,1355
# ディアスタッフ株式会社_採用窓口【003】※品川エリア【案件No.10】,1500
# ディアスタッフ株式会社_採用窓口【003】※品川エリア【案件No.589】,1500
# 株式会社ルフト・メディカルケア（新橋）,1900
# 株式会社ホリウチ・トータルサービス　品川エリア,1250
# 株式会社グランシーズ（田町エリアのお仕事）お仕事NO_001,1400
# 株式会社グランシーズ（田町エリアのお仕事）お仕事NO_001,1400
# 株式会社ルフト・メディカルケア（乃木坂）,2000
# 株式会社グランシーズ（六本木エリアのお仕事）お仕事NO_001,1400
# 株式会社インテルノス アラジンケア事業部 ※表参道駅エリア,2300
# 株式会社グランシーズ（神谷町エリアのお仕事）お仕事NO_001,1400
# 株式会社グランシーズ（外苑前エリアのお仕事）お仕事NO_001,1400
# 株式会社ホリウチ・トータルサービス　青山一丁目エリア,1250
# ディアスタッフ株式会社_採用窓口【003】※御成門エリア【案件No.589】,1500
# 株式会社ルフト・メディカルケア（六本木）,2000
# 株式会社グランシーズ（青山一丁目エリアのお仕事）お仕事NO_001,1400
# 株式会社ルフト・メディカルケア（大門）,1900
# 株式会社グランシーズ（神谷町エリアのお仕事）お仕事NO_001,1400
# 株式会社グランシーズ（新橋エリアのお仕事）お仕事NO_001,1400
# 株式会社ルフト・メディカルケア（赤坂）,1900
# ヨウコーほっとスタッフ,1900
# 株式会社グランシーズ（品川エリアのお仕事）お仕事NO_001,1400
# 株式会社ルフト・メディカルケア（赤坂見附）,2000
# ヨウコーほっとスタッフ,1900
# テイケイワークス株式会社　池袋支店/TW153,1500
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社ルフト・メディカルケア（広尾）,1900
# テイケイワークス東京　川崎支店/TWT162,1242
# ディアスタッフ株式会社_採用窓口【003】※表参道エリア【案件No.589】,1500
# 株式会社グランシーズ（田町エリアのお仕事）お仕事NO_001,1400
# ディアスタッフ株式会社_採用窓口【003】※広尾エリア【案件No.589】,1500
# 株式会社アシスト 新宿本社,1750
# ディアスタッフ株式会社_採用窓口【003】※品川エリア【案件No.10】,1750
# テイケイワークス東京　新宿支店/TWT160,1312
# ディアスタッフ株式会社_採用窓口【003】※田町エリア【案件No.589】,1500
# 株式会社グランシーズ（新橋エリアのお仕事）お仕事NO_001,1400
# 株式会社グランシーズ（新橋エリアのお仕事）お仕事NO_001,1400
# 株式会社アシスト 新宿本社,1750
# 株式会社グランシーズ（外苑前エリアのお仕事）お仕事NO_001,1400
# 株式会社グランシーズ（六本木エリアのお仕事）お仕事NO_001,1400
# 株式会社ルフト・メディカルケア（青山一丁目）,2000
# 株式会社グランシーズ（外苑前エリアのお仕事）お仕事NO_001,1400
# ディアスタッフ株式会社_採用窓口【003】※赤羽橋エリア【案件No.589】,1500
# 株式会社リージェンシー 関東支社/KTMBSS0006f,1500
# 株式会社エスケイコンサルタント　新宿支店/sk703,1332
# 株式会社グランシーズ（青山一丁目エリアのお仕事）お仕事NO_001,1400
# 株式会社グランシーズ（外苑前エリアのお仕事）お仕事NO_001,1400
# 株式会社グランシーズ（田町エリアのお仕事）お仕事NO_001,1400
# 株式会社ルフト・メディカルケア（神谷町）,2000
# 株式会社ルフト・メディカルケア　お仕事No.211 白金高輪駅,1900
# 株式会社グランシーズ（品川エリアのお仕事）お仕事NO_001,1400
# 株式会社ホリウチ・トータルサービス　六本木エリア,1250
# 株式会社グランシーズ（青山一丁目エリアのお仕事）お仕事NO_001,1400
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# ディアスタッフ株式会社_採用窓口【003】※虎ノ門エリア【案件No.589】,1500
# 日本トスコム株式会社 新宿支店/101,1302
# 株式会社ルフト・メディカルケア（麻布十番）,2000
# テイケイワークス株式会社　池袋支店/TW153,1350
# 株式会社ルフト・メディカルケア（白金台）,2000
# 株式会社アシスト 新宿本社,1750
# 株式会社アシスト 新宿本社,1750
# 株式会社アシスト 新宿本社,1750
# 株式会社ホリウチ・トータルサービス　田町エリア,1250
# 株式会社グランシーズ（神谷町エリアのお仕事）お仕事NO_001,1400
# ヨウコーほっとスタッフ,1900
# ヨウコーほっとスタッフ,1900
# 株式会社ルフト・メディカルケア（表参道）,1900
# 株式会社アシスト 新宿本社,1750
# 株式会社ルフト・メディカルケア（白金高輪）,1900
# 株式会社グランシーズ（田町エリアのお仕事）お仕事NO_001,1400
# 株式会社リージェンシー 関東支社/KTMBSS0005f,1450
# ディアスタッフ株式会社_採用窓口【003】※北品川エリア【案件No.589】,1500
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社ルフト・メディカルケア（芝公園）,2000
# 株式会社ホリウチ・トータルサービス　赤坂見附エリア,1250
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社グランシーズ（六本木エリアのお仕事）お仕事NO_001,1400
# 株式会社インテルノス アラジンケア事業部 ※高輪台駅エリア,2300
# 株式会社グランシーズ（品川エリアのお仕事）お仕事NO_001,1400
# 株式会社ルフト・メディカルケア（赤羽橋）,1900
# 株式会社マイワーク　錦糸町営業所　（2590112000※AP・派遣）,1370
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社マイワーク　錦糸町営業所　（2590112000※AP・派遣）,1370
# 株式会社バイトレ【MBT670647】,1550
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイトレード株式会社　新宿支店/521,1312
# 株式会社マイワーク　錦糸町営業所　（2590112000※AP・派遣）,1370
# 全国試験運営センター　(※新橋エリア),1190
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# 株式会社ワークオール/池袋本社　［乃木坂エリア］,1200
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 全国試験運営センター　(※表参道エリア),1190
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社ホリウチ・トータルサービス　六本木一丁目エリア,1250
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# 株式会社バイトレ【MBT675304】,1550
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社バイトレ【MBT689873】,1470
# 株式会社バイトレ【MBT693867】,1800
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社マイワーク　錦糸町営業所　（2590112000※AP・派遣）,1370
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社ワン＆オンリーキャスティング（派遣先：表参道エリア）,1500
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイワークス株式会社　新宿中央支店/TW110,1500
# 株式会社ワン＆オンリーキャスティング（派遣先：田町エリア）,1163
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社ワン＆オンリーキャスティング（派遣先：新橋エリア）,1500
# 株式会社バイトレ【MBT688630】,1350
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# テイケイワークス株式会社　川崎支店/TW145,1262
# テイケイトレード株式会社　新宿支店/521,1306
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイトレード株式会社　錦糸町支店/505,1281
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社サウンズグッド　新宿支店/sjkL0000,1350
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社ワン＆オンリーキャスティング（派遣先：品川エリア）,1163
# 株式会社ホリウチ・トータルサービス　品川エリア,1250
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# テイケイトレード株式会社　新宿支店/521,1251
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社バイトレ【MB810903GT03】,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイネクスト株式会社　川崎支店/TN107,1258
# 全国試験運営センター　(※品川エリア),1190
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社サウンズグッド　ｽﾄｱｻﾎﾟｰﾄ支店/sjkS0000,1290
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社バイトレ【MBT696328】,1314
# 株式会社ワン＆オンリーキャスティング（派遣先：六本木エリア）,1500
# 株式会社ワークオール/池袋本社　［大門エリア］,1200
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイネクスト株式会社　川崎支店/TN107,1258
# テイケイワークス株式会社　新宿中央支店/TW110,1300
# テイケイネクスト株式会社　川崎支店/TN107,1258
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイトレード株式会社　錦糸町支店/505,1260
# テイケイトレード株式会社　新宿支店/521,1351
# テイケイトレード株式会社　新宿支店/521,1252
# テイケイワークス株式会社　新宿中央支店/TW110,1600
# テイケイトレード株式会社　新宿支店/521,1280
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイワークス株式会社　新宿中央支店/TW110,1300
# 株式会社ワン＆オンリーキャスティング（派遣先：芝公園エリア）,1500
# 株式会社バイトレ【MBT687600】,1520
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社バイトレ【MBT688706】,1570
# 株式会社バイトレ【MBT675302】,1800
# 株式会社バイトレ【MBT696447】,1400
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社バイトレ【MBT694311】,1350
# 株式会社バイトレ【MBT678811】,1350
# テイケイトレード株式会社　新宿支店/521,1306
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社バイトレ【MBT694326】,1350
# 株式会社マイワーク　蒲田営業所　（2590112000※AP・派遣）,1450
# 株式会社バイトレ【MB810903GT03】,1300
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社マイワーク　渋谷営業所　（2590112000※AP・派遣）,1500
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社ワン＆オンリーキャスティング（派遣先：浜松町エリア）,1163
# ==== CSV出力が完了しました ====

# %% [markdown]
# #### 足立区のスクレイピング

# %%
import re
import csv
import time
import requests
from bs4 import BeautifulSoup

def scrape_and_save_to_csv(base_url, csv_filename, max_pages=50):
    """
    base_url:
        ページ番号以外の共通部分。末尾に「?pageNo={page}」を付与して利用します。

    csv_filename:
        CSV出力のファイル名。

    max_pages:
        安全のための最大ページ数。デフォルトは50ですが、必要に応じて増減してください。
    """

    results = []

    # 正規表現パターン: "1600" の直後に4桁の数字が続くか → "1600" に置換
    pattern_remove_1600 = re.compile(r'1600\d{4}')

    for page_no in range(1, max_pages+1):
        # ページURL生成
        url = f"{base_url}?pageNo={page_no}"

        print(f"Fetching page: {url}")

        # リクエスト 前に3秒待機
        time.sleep(3)

        # ページ取得
        response = requests.get(url)
        # エラーなどでページが存在しない場合はそこで終了
        if response.status_code != 200:
            print(f"Page {page_no} not found (status: {response.status_code}). Stop.")
            break

        html_content = response.text
        soup = BeautifulSoup(html_content, 'html.parser')

        # カード単位で求人情報を取得（構造によって変更してください）
        # 例: "section.jobOfferCard" など、実際のHTMLを確認して適宜変更。
        # 以下は汎用的に "section" を全部取ってきて、その中に会社名・時給があるかを探す例。
        cards = soup.find_all("section")

        # フラグ: 1ページ分のcardが0件 または 有効なcardが何もない → 次のページ無さそうなら終了
        valid_card_found = False

        for card in cards:
            # 会社名を取得
            company_name_elem = card.select_one("div.shopNameWrap > h2")
            if not company_name_elem:
                continue
            company_name = company_name_elem.get_text(strip=True)

            # 時給を取得
            wage_elem = card.select_one("li.baseInformationSet.wage > div.baseInformationFirstContent")
            if not wage_elem:
                continue

            wage_text_original = wage_elem.get_text(strip=True)

            # "1600" のあとに4桁の数字 → "1600" に置換
            wage_text_fixed = re.sub(pattern_remove_1600, '1600', wage_text_original)

            # 数値抽出
            # 例: "時給1600～2000円" → ['1600','2000']
            # 最初の数字を最低時給とする
            nums = re.findall(r'\d+', wage_text_fixed)
            if not nums:
                continue

            min_wage = int(nums[0])  # 最初の数字を最低時給とみなす

            # 3桁以下(例: 100 ~ 999以下)は無視する
            if min_wage < 1000:
                # 例: 900とか700は日当表記などの可能性があるのでスキップ
                continue

            # ここまでこれたら有効データ
            valid_card_found = True

            results.append({
                "company_name": company_name,
                "wage_info": min_wage
            })

        # 有効なカードが0件の場合は「次のページはない」と判断して終了してもよい
        # ただし、中には他のページがまだある場合もあるので、判断が難しい場合は
        # ここでは card が見つからなくても break はしないことにします。
        # もし、次ページでは求人が本当にない、かつ 404 にもならないケースがあれば
        # 追加で条件を入れる必要があります。
        if not valid_card_found:
            print(f"No valid job found on page {page_no}. Stop.")
            break

    # すべてのページを取得後、CSV出力
    with open(csv_filename, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=["company_name", "wage_info"])
        writer.writeheader()
        writer.writerows(results)

    # コンソールにも出力確認
    for row in results:
        print(f"{row['company_name']},{row['wage_info']}")


if __name__ == "__main__":
    # base_url は「?pageNo=」より前の部分
    # 例: "https://baito.mynavi.jp/tokyo/city-34/kd-11_3101/"
    base_url = "https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/"
    csv_filename = "wage_info.csv"

    scrape_and_save_to_csv(base_url, csv_filename)
    print("==== CSV出力が完了しました ====")
# Out:
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=1
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=2
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=3
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=4
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=5
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=6
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=7
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=8
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=9
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=10
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=11
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=12
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=13
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=14
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=15
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=16
# Fetching page: https://baito.mynavi.jp/tokyo/city-52/kd-11_3101/?pageNo=17
# No valid job found on page 17. Stop.
# 株式会社ハイスタッフ　※足立エリア　(001),1300
# 株式会社ハイスタッフ　※足立エリア　(001),1300
# 株式会社ムーヴ　※北千住エリア,1300
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社エボルカ/東京本社,1500
# 株式会社エボルカ/東京本社,1500
# 株式会社アシスト 新宿本社,1750
# エースパワー株式会社 池袋本社,1750
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社栗原洋服店　北千住エリア,1400
# ピザーラ　北千住店,1400
# ピザーラ　北千住店,1400
# ピザーラ　北千住店,1400
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※竹ﾉ塚ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※六町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※舎人ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:扇橋交通株式会社本社営業所)※竹ﾉ塚ｴﾘｱ,1400
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※西新井ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※北千住ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※六町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※六町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※千住大橋ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※西新井ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※舎人ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※北千住ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※竹ﾉ塚ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※六町ｴﾘｱ,2000
# 株式会社ビッグワーク 採用センター【BW03】,1200
# 株式会社ワークオール/池袋本社　［北千住エリア］,1200
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※綾瀬ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※京成関屋ｴﾘｱ,1800
# ビギニングジャパン株式会社［綾瀬エリア］,1200
# 紹介元:GO株式会社(紹介先:扇橋交通株式会社本社営業所)※綾瀬ｴﾘｱ,1400
# 紹介元:GO株式会社(紹介先:扇橋交通株式会社本社営業所)※北千住ｴﾘｱ,1400
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※竹ﾉ塚ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※綾瀬ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※北千住ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※西新井ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※舎人ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※舎人ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※綾瀬ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※綾瀬ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※竹ﾉ塚ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※北千住ｴﾘｱ,2000
# ビギニングジャパン株式会社［綾瀬エリア］,1200
# テイケイネクスト株式会社　松戸支店/TN518S0103MB01,1258
# 紹介元:GO株式会社(紹介先:日本交通立川株式会社立川･本社営業所)※北千住ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:梅田交通ｸﾞﾙｰﾌﾟ東京梅田交通株式会社)※大師前ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社赤羽営業所)※西新井ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※北綾瀬ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※竹ﾉ塚ｴﾘｱ,1500
# 紹介元:GO株式会社(紹介先:すばる交通株式会社北千住営業所)※北千住ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※竹ﾉ塚ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※綾瀬ｴﾘｱ,2000
# 株式会社サカイ引越センター　東関東Bブロック 五反野エリア【073】,1350
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※舎人ｴﾘｱ,1800
# テイケイトレード株式会社　北千住支店/523,1315
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※六町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※北綾瀬ｴﾘｱ,1500
# 株式会社サンライズ　池袋営業所,1750
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※西新井ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※西新井ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社赤羽営業所)※綾瀬ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※大師前ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※北綾瀬ｴﾘｱ,1800
# 株式会社ネクスト　※勤務地：東京都足立区,1200
# 株式会社サカイ引越センター　東関東Bブロック 江北エリア【073】,1350
# 株式会社橘組　東京営業所,2000
# テイケイトレード株式会社　北千住支店/523,1314
# 株式会社麻野配ぜん人紹介所　勤務地：北千住駅周辺エリア【001】,1600
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※京成関屋ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※綾瀬ｴﾘｱ,1800
# テイケイトレード株式会社　北千住支店/523,1315
# 株式会社サンライズ　池袋営業所,1750
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※舎人公園ｴﾘｱ,2000
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※北千住ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※綾瀬ｴﾘｱ,1500
# 有限会社あさのコーポレーション　勤務地：綾瀬駅周辺【001】,1600
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※西新井ｴﾘｱ,1500
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイトレード株式会社　北千住支店/523,1252
# テイケイトレード株式会社　北千住支店/523,1215
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※見沼代親水公園ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※北綾瀬ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※北千住ｴﾘｱ,2000
# 株式会社サカイ引越センター　東関東Bブロック 竹ノ塚エリア【073】,1350
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社赤羽営業所)※西新井ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社赤羽営業所)※西新井ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※五反野ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※六町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※足立小台ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※北綾瀬ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※五反野ｴﾘｱ,2000
# 株式会社スギハラサービスクリエイツ　綾瀬駅,1600
# 株式会社free mova（勤務地：北千住エリア）,1500
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※北千住ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※青井ｴﾘｱ,2000
# 株式会社橘組　東京営業所,2000
# 株式会社ネクスト　※勤務地：東京都足立区,1200
# 株式会社LOCCo,1300
# 紹介元:GO株式会社(紹介先:すばる交通株式会社北千住営業所)※竹ﾉ塚ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※六町ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社赤羽営業所)※北千住ｴﾘｱ,1800
# 株式会社ネクスト　※勤務地：東京都足立区,1200
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※綾瀬ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※足立小台ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※京成関屋ｴﾘｱ,2000
# 株式会社橘組　東京営業所,2000
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※見沼代親水公園ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※千住大橋ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※西新井大師西ｴﾘｱ,1800
# 株式会社スギハラサービスクリエイツ　北千住駅,1600
# 株式会社サカイ引越センター　東関東Bブロック 舎人エリア【073】,1350
# 株式会社サカイ引越センター　東関東Bブロック 舎人エリア【073】,1350
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※西新井ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※梅島ｴﾘｱ,1800
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※見沼代親水公園ｴﾘｱ,2000
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※舎人公園ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※西新井大師西ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※亀有ｴﾘｱ,2000
# 有限会社　BELL STAFF　※足立エリア　入谷(001),1340
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※北千住ｴﾘｱ,1500
# 株式会社サンライズ　池袋営業所,1750
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※西新井ｴﾘｱ,1800
# アリさんマークの引越社　越谷支店（勤務地：北千住駅周辺）,1350
# テイケイトレード株式会社　北千住支店/523,1250
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※舎人ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※西新井大師西ｴﾘｱ,1500
# 紹介元:GO株式会社(紹介先:すばる交通株式会社北千住営業所)※綾瀬ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※千住大橋ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※竹ﾉ塚ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※京成関屋ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※六町ｴﾘｱ,1500
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※西新井大師西ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社赤羽営業所)※竹ﾉ塚ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※西新井大師西ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※五反野ｴﾘｱ,1500
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※大師前ｴﾘｱ,1800
# 株式会社サカイ引越センター　東関東Bブロック 西新井エリア【073】,1350
# 株式会社クリーンプラザ　勤務地：北千住エリア,1200
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※六町ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※江北ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※京成関屋ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※北綾瀬ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※千住大橋ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※谷塚ｴﾘｱ,1800
# 株式会社サンライズ　池袋営業所,1750
# 株式会社スギハラサービスクリエイツ　北千住エリア,1600
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※京成関屋ｴﾘｱ,1500
# テイケイトレード株式会社　北千住支店/523,1313
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社サカイ引越センター　東関東Bブロック 扇大橋エリア【073】,1350
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※西新井ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※舎人公園ｴﾘｱ,1800
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 全国試験運営センター　(※北千住エリア),1190
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※千住大橋ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※梅島ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※梅島ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※大師前ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※高野ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※梅島ｴﾘｱ,1800
# 株式会社ワークオール/池袋本社　［王子エリア］,1200
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※梅島ｴﾘｱ,1500
# 株式会社ワークオール/池袋本社　［梅島エリア］,1200
# 紹介元:GO株式会社(紹介先:飛鳥交通株式会社赤羽営業所)※舎人ｴﾘｱ,1800
# テイケイトレード株式会社　北千住支店/523,1215
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※綾瀬ｴﾘｱ,1800
# 株式会社サンライズ　池袋営業所,1750
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# テイケイトレード株式会社　北千住支店/523,1314
# 株式会社サカイ引越センター　東関東Bブロック 北千住エリア【073】,1350
# 紹介元:GO株式会社(紹介先:実用興業株式会社本社営業所)※舎人ｴﾘｱ,1500
# 株式会社ムーヴ　※西新井エリア,1300
# 株式会社橘組　東京営業所,2000
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※西新井大師西ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※江北ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※足立小台ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※五反野ｴﾘｱ,1800
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社橘組　東京営業所,2000
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※舎人ｴﾘｱ,2000
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社サカイ引越センター　東関東Bブロック 綾瀬エリア【073】,1350
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※谷塚ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:すばる交通株式会社北千住営業所)※舎人ｴﾘｱ,1800
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※西新井大師西ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※北千住ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※竹ﾉ塚ｴﾘｱ,1800
# 株式会社スカイ・エッヂ (勤務地：北千住エリア),1500
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※竹ﾉ塚ｴﾘｱ,2000
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第一営業所)※梅島ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社北千住営業所)※西新井ｴﾘｱ,1800
# 株式会社ワークオール/池袋本社　［舎人エリア］,1200
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※舎人ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※北綾瀬ｴﾘｱ,1800
# 株式会社ネクスト　※勤務地：東京都足立区,1200
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※五反野ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:東京合同自動車株式会社本社営業所)※谷塚ｴﾘｱ,1800
# 紹介元:GO株式会社(紹介先:すばる交通株式会社第二営業所)※大師前ｴﾘｱ,1800
# テイケイトレード株式会社　北千住支店/523,1252
# 紹介元:GO株式会社(紹介先:日本交通株式会社千住営業所)※江北ｴﾘｱ,2000
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社レジェンドプロモーション／※勤務地：北千住駅周辺,1700
# 株式会社フルキャスト　東京支社　（綾瀬エリア）/MN0124G-AGM,1165
# 株式会社フルキャスト　東京支社　（綾瀬エリア）/MN0124G-AGM,1165
# 株式会社レジェンドプロモーション／※勤務地：西新井駅周辺,1700
# 株式会社フルキャスト　東京支社　（西新井大師西エリア）/MN0124G-ADQ,1200
# 株式会社フルキャスト　東京支社　（竹ノ塚エリア）/MN0124G-ADW,1250
# 株式会社レジェンドプロモーション／※勤務地：北綾瀬駅周辺,1700
# 株式会社フルキャスト　東京支社　（扇大橋エリア）/MN0124G-AEW,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイワークス東京　新宿支店/TWT160,1315
# テイケイワークス東京　新宿支店/TWT160,1223
# 株式会社サンライズ　池袋営業所,1750
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 日本トスコム株式会社 池袋支店/104,1302
# 株式会社リージェンシー 関東支社/KTMBSS0627p,1350
# 株式会社ルフト・メディカルケア　お仕事No.195 竹ノ塚駅,2100
# 株式会社リージェンシー 関東支社/KTMBSS0177f,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイワークス株式会社　柏支店/TW108,1258
# 株式会社グランシーズ（綾瀬エリアのお仕事）お仕事NO_001,1400
# テイケイネクスト株式会社　松戸支店/TN518S0103MB13,1258
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイネクスト株式会社　松戸支店/TN518S0103MB28,1258
# 株式会社アシスト 新宿本社,1750
# エースパワー株式会社 池袋本社,1750
# エースパワー株式会社 池袋本社,1750
# 株式会社ルフト・メディカルケア　お仕事No.674 竹ノ塚駅,2100
# 株式会社グランシーズ（西新井エリアのお仕事）お仕事NO_001,1400
# 株式会社LOCCo,1300
# 株式会社リージェンシー 関東支社/KTMBSS0010p,1350
# 株式会社レジェンドプロモーション　 （※勤務地：西新井駅周辺）-mb,1700
# 株式会社レジェンドプロモーション　 （※勤務地：西新井駅周辺）-mb,1700
# 株式会社サンライズ　池袋営業所,1750
# 株式会社インテルノス アラジンケア事業部 ※北千住駅エリア,2300
# エースパワー株式会社 池袋本社,1750
# テイケイネクスト株式会社　松戸支店/TN518S0103MB17,1258
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社グランシーズ（北千住エリアのお仕事）お仕事NO_001,1400
# 株式会社アシスト 新宿本社,1750
# 株式会社サンライズ　池袋営業所,1750
# 株式会社サンライズ　池袋営業所,1750
# 株式会社ハンズキャリア　東京支店【999】,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイネクスト株式会社　松戸支店/TN518S0103MB19,1258
# 株式会社グランシーズ（北千住エリアのお仕事）お仕事NO_001,1400
# エースパワー株式会社 池袋本社,1750
# 株式会社グランシーズ（綾瀬エリアのお仕事）お仕事NO_001,1400
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社ホリウチ・トータルサービス　六町エリア,1250
# 株式会社グランシーズ（西新井エリアのお仕事）お仕事NO_001,1400
# パーソナルエージェントホールディングス株式会社　北千住エリア,1200
# エースパワー株式会社 池袋本社,1750
# 株式会社サンライズ　池袋営業所,1750
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# ヨウコーほっとスタッフ,1900
# 株式会社アシスト 新宿本社,1750
# 株式会社グランシーズ（綾瀬エリアのお仕事）お仕事NO_001,1400
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社グランシーズ（西新井エリアのお仕事）お仕事NO_001,1400
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社ホリウチ・トータルサービス　北千住エリア,1250
# 株式会社グランシーズ（北千住エリアのお仕事）お仕事NO_001,1400
# 株式会社グランシーズ（北千住エリアのお仕事）お仕事NO_001,1400
# 株式会社まなびーいんぐ　【北千住】,2500
# パーソナルエージェントホールディングス株式会社　北千住エリア,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社グランシーズ（綾瀬エリアのお仕事）お仕事NO_001,1400
# 株式会社エスケイコンサルタント　南越谷支店/sk710,1287
# 株式会社グランシーズ（北千住エリアのお仕事）お仕事NO_001,1400
# 株式会社ヨウコーほっとスタッフ,1900
# パーソナルエージェントホールディングス株式会社　西新井エリア,1200
# 株式会社グランシーズ（西新井エリアのお仕事）お仕事NO_001,1400
# テイケイワークス株式会社　大宮支店/TW143,1200
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社バイトレ【MB810111GT08】,1300
# テイケイトレード株式会社　北千住支店/523,1252
# ビギニングジャパン株式会社［北千住エリア］,1200
# 株式会社バイトレ【MBT696344】,1200
# テイケイトレード株式会社　北千住支店/523,1292
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# テイケイワークス株式会社　南越谷支店/TW123,1262
# テイケイトレード株式会社　北千住支店/523,1252
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# ワンダーグループ株式会社　東京本社【001】,1163
# テイケイワークス株式会社　大宮支店/TW143,1200
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイトレード株式会社　北千住支店/523,1300
# テイケイトレード株式会社　北千住支店/523,1314
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイトレード株式会社　北千住支店/523,1250
# テイケイネクスト株式会社　松戸支店/TN518,1258
# 株式会社ワークオール/池袋本社　［亀有エリア］,1200
# 株式会社バイトレ【MB810111GT06】,1300
# 株式会社バイトレ【MB810111GT07】,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイワークス株式会社　大宮支店/TW143,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# パーソナルエージェントホールディングス株式会社　竹ノ塚エリア,1200
# 株式会社ワークオール/池袋本社　［亀有エリア］,1200
# テイケイワークス株式会社　新宿中央支店/TW110,1350
# 株式会社バイトレ【MBT678845】,1200
# テイケイネクスト株式会社　松戸支店/TN518,1258
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社バイトレ【MBT674314】,1500
# 株式会社ワークオール/池袋本社　［北綾瀬エリア］,1200
# 株式会社バイトレ【MB810111GT08】,1300
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# テイケイネクスト株式会社　松戸支店/TN518,1258
# テイケイトレード株式会社　北千住支店/523,1252
# 株式会社ワークオール/池袋本社　［千住大橋エリア］,1200
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社バイトレ【MB810111GT06】,1300
# 株式会社バイトレ【MBT688025】,1400
# テイケイトレード株式会社　北千住支店/523,1314
# 株式会社バイトレ【MB810111GT08】,1300
# テイケイネクスト株式会社　松戸支店/TN518,1258
# テイケイワークス株式会社　大宮支店/TW143,1200
# 株式会社バイトレ【MB810111GT09】,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社バイトレ【MB810111GT09】,1300
# 株式会社ワン＆オンリーキャスティング（派遣先：北千住エリア）,1163
# 株式会社ワン＆オンリーキャスティング（派遣先：北千住エリア）,1500
# 株式会社サウンズグッド　ｽﾄｱｻﾎﾟｰﾄ支店/sjkS0000,1290
# ビギニングジャパン株式会社［竹ノ塚エリア］,1200
# 株式会社ワン＆オンリーキャスティング（派遣先：綾瀬エリア）,1163
# 株式会社ワン＆オンリーキャスティング（派遣先：竹ノ塚エリア）,1163
# テイケイワークス株式会社　池袋支店/TW153,1350
# 株式会社サウンズグッド　新宿支店/sjkL0000,1350
# テイケイネクスト株式会社　松戸支店/TN518,1258
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイトレード株式会社　北千住支店/523,1314
# テイケイワークス株式会社　南越谷支店/TW123,1262
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社サウンズグッド　新宿支店/sjkL0000,1350
# 株式会社バイトレ【MBT693557】,1305
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 全国試験運営センター　(※綾瀬エリア),1190
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社バイトレ【MBT693556】,1305
# テイケイトレード株式会社　北千住支店/523,1250
# テイケイトレード株式会社　北千住支店/523,1250
# テイケイワークス株式会社　新宿中央支店/TW110,1350
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社バイトレ【MB810111GT06】,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# ビギニングジャパン株式会社［北綾瀬エリア］,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社ワン＆オンリーキャスティング（派遣先：京成関屋エリア）,1163
# テイケイトレード株式会社　北千住支店/523,1252
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# 株式会社ホリウチ・トータルサービス　北千住エリア,1250
# 株式会社バイトレ【MB810111GT07】,1300
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイトレード株式会社　北千住支店/523,1252
# テイケイネクスト株式会社　松戸支店/TN518,1258
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイネクスト株式会社　松戸支店/TN518,1258
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# テイケイネクスト株式会社　松戸支店/TN518,1258
# 株式会社バイトレ【MBT692606】,1163
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイワークス株式会社　池袋支店/TW153,1350
# テイケイワークス株式会社　池袋支店/TW153,1350
# ビギニングジャパン株式会社［北綾瀬エリア］,1200
# ビギニングジャパン株式会社［北綾瀬エリア］,1200
# 株式会社サウンズグッド　新宿支店/sjkL0000,1350
# ビギニングジャパン株式会社［北千住エリア］,1200
# 株式会社ワークオール/池袋本社　［京成関屋エリア］,1200
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社バイトレ【MB810111GT07】,1300
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社セレブリックス　コンビニスタッフプロモーション 【KT】※博報堂プロダクツグループ,1300
# ビギニングジャパン株式会社［綾瀬エリア］,1200
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# ビギニングジャパン株式会社［綾瀬エリア］,1200
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# 株式会社バイトレ【MBT692221】,1500
# 株式会社エントリー 新宿 [1]・【HNS】,1200
# テイケイワークス株式会社　大宮支店/TW143,1200
# 株式会社ワン＆オンリーキャスティング（派遣先：西新井エリア）,1163
# ビギニングジャパン株式会社［竹ノ塚エリア］,1200
# 株式会社ワークオール/池袋本社　［京成関屋エリア］,1200
# テイケイワークス株式会社　大宮支店/TW143,1200
# ビギニングジャパン株式会社［西新井エリア］,1200
# テイケイトレード株式会社　北千住支店/523,1250
# 株式会社マイワーク　北千住営業所　（2590112000※AP・派遣）,1300
# テイケイワークス株式会社　南越谷支店/TW123,1262
# テイケイワークス株式会社　南越谷支店/TW123,1262
# 株式会社バイトレ【MBT693862】,1550
# 株式会社バイトレ【MB810111GT09】,1300
# ==== CSV出力が完了しました ====
